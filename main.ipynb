# %%
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp

from data_classes import State, Control, VolumeElements
from solver import FVEulerSolver
from adjoint_solver import AdjointFVEulerSolver
from optimizer import Optimizer
from plotting_utils import plot_densities, plot_controls, plot_all_residuals, plot_objective

# %%
# 1. Spatial domains
edges = jnp.linspace(0.0, 25.0, 801)
ve   = VolumeElements.from_edges(edges)
centres = ve.centers

# %%
# 2. Time discretization
t     = jnp.linspace(0.0, 1.0, 801)
dt    = t[1] - t[0]

# %%
# Example parameters

K0 = 0.05  
a0 = 0.2
lam = 1/2
nu = 0.0 # 0 #  -1 < nu <= inf
K_fun     = lambda x,y : K0 * jnp.where( x + y <= 25, (1 + x)**0.25 * (1+y)**0.25 , 0.0)     # coagulation kernel
alpha_fun = lambda x: a0 * x ** lam                                                         # fragmentation rate
b_fun     = lambda x, y: (2.0 + nu) / y * (x / y) ** nu                                     # daughter distribution

# Initial conditions
centre = 7.5
f0 = jnp.where(centres <= 25, 1.0 * jnp.exp( - (centres - centre) ** 2 /50 ), 0.0)
state0  = State(f0, centres)

# running cost weight
weight = 0.2

sign = 1.0 # -1 for maximization, +1 for minimization

u_min = 0.5
u_max = 4.0

output_dir = 'test_case_paper'

# %%
# Example costs

# Target region
lower_bound = 0.0 # minimum size of particles in target region
upper_bound = 5.0 # maximum size of particles in target region

def chi(x: jax.Array, lb: jax.Array, ub: jax.Array) -> jax.Array:
    i = jnp.logical_and(x >= lb, x <= ub)
    return jnp.where(i, 1.0, 0.0)

def psi(f: jax.Array, x: jax.Array, lb: jax.Array, ub: jax.Array) -> jax.Array:
    dx = x[1] - x[0]
    return jnp.sum(f * chi(x, lb, ub) * dx)

# terminal cost
def terminal_cost(f: State) -> jax.Array:
    return sign * psi(f.f, f.centers, lower_bound, upper_bound)

def terminal_cost_grad(f: State) -> jax.Array:
    return sign * chi(f.centers, lower_bound, upper_bound)

# running cost
def running_cost(control: Control) -> jax.Array:
    dt = control.times[1] - control.times[0]
    running_cost = 0.5 * weight * jnp.sum((control.values - 1.0) ** 2) * dt
    return running_cost

def running_cost_grad(control: Control) -> jax.Array:
    return weight * (control.values - 1.0)

# %%
# ------------------------------------
#      Solvers and optimizer
# ------------------------------------

solver = FVEulerSolver(ve, t, K_fun, alpha_fun, b_fun, mass_fix = 'no')

adjoint_solver = AdjointFVEulerSolver(ve, t, K_fun, alpha_fun, b_fun)

opt = Optimizer(
    init_state     = state0,
    forward_solver = solver,
    adjoint_solver = adjoint_solver,
    terminal_cost  = terminal_cost,
    terminal_cost_grad = terminal_cost_grad,
    running_cost = running_cost,
    running_cost_grad = running_cost_grad,
    weight = weight,
    u_min = u_min, u_max = u_max,
    max_ls_iter = 20,
    armijo_rho = 0.5,
    armijo_sigma = 0.001,
    verbose = True
)

# %%
# --------------------------------------------------------------------
# 5.  Optimisation
# --------------------------------------------------------------------

# 5.1 Optimization routine

u0 = jnp.ones_like(t) # no control

print("\n--- optimise with adjoint ---")
out_adj = opt.pgd_adjoint(1.0 * u0, lr=0.1, n_iter=40, tolerance = 1e-1)
u_adj, J_adj, terminal_cost_adj, grad_hist, delta_control_adj, delta_H_adj, res_hist_adj, loss_hist_adj, terminal_hist_adj, it_final = out_adj

# 5.2  Re-run forward solver to obtain full trajectorie
optimal_control = Control(u_adj, t)
no_control = Control(1.0 * u0, t)

state_T_adj, traj_adj = solver.solve(initial_state=state0, control=optimal_control)
state_T_no_control, traj_no_control = solver.solve(initial_state=state0, control=no_control)

J_1 = opt.total_cost(traj_no_control, no_control)
terminal_cost_1 = opt.terminal_cost(state_T_no_control)

print(f"No control   J_no:con  = {float(J_1):.6e}, terminal cost = {float(terminal_cost_1):6e}")

# 5.2 Mass loss diagnostics

rel_mass_loss = (state0.first_moment()-state_T_adj.first_moment())/ state0.first_moment()
print(rel_mass_loss)
# Out:
# --- optimise with adjoint ---
# iter 000,  delta_control_rel=7.500e-01, delta_H_rel=7.306e-01 ||g||=3.001e+00, J=4.378182e+00 terminal_cost = 4.3781819343566895
# iter 001, ls=0, delta_control_rel=6.780e-01, delta_H_rel=6.308e-01 res=2.637e+00, ||g||=3.001e+00, J=3.617155e+00 terminal_cost = 3.6081457138061523
# iter 002, ls=0, delta_control_rel=6.276e-01, delta_H_rel=5.555e-01 res=2.025e+00, ||g||=2.135e+00, J=3.211119e+00 terminal_cost = 3.184744119644165
# iter 003, ls=0, delta_control_rel=5.883e-01, delta_H_rel=4.934e-01 res=1.645e+00, ||g||=1.693e+00, J=2.949458e+00 terminal_cost = 2.9028425216674805
# iter 004, ls=0, delta_control_rel=5.561e-01, delta_H_rel=4.402e-01 res=1.384e+00, ||g||=1.411e+00, J=2.764976e+00 terminal_cost = 2.6971187591552734
# iter 005, ls=0, delta_control_rel=5.289e-01, delta_H_rel=3.937e-01 res=1.192e+00, ||g||=1.211e+00, J=2.627707e+00 terminal_cost = 2.538447856903076
# iter 006, ls=0, delta_control_rel=5.049e-01, delta_H_rel=3.524e-01 res=1.043e+00, ||g||=1.060e+00, J=2.521801e+00 terminal_cost = 2.4114105701446533
# iter 007, ls=0, delta_control_rel=4.807e-01, delta_H_rel=3.156e-01 res=9.236e-01, ||g||=9.412e-01, J=2.437934e+00 terminal_cost = 2.306913137435913
# iter 008, ls=0, delta_control_rel=4.567e-01, delta_H_rel=2.826e-01 res=8.250e-01, ||g||=8.442e-01, J=2.370195e+00 terminal_cost = 2.219175338745117
# iter 009, ls=0, delta_control_rel=4.333e-01, delta_H_rel=2.529e-01 res=7.416e-01, ||g||=7.634e-01, J=2.314633e+00 terminal_cost = 2.144313335418701
# iter 010, ls=0, delta_control_rel=4.107e-01, delta_H_rel=2.262e-01 res=6.698e-01, ||g||=6.948e-01, J=2.268488e+00 terminal_cost = 2.079601764678955
# iter 011, ls=0, delta_control_rel=3.891e-01, delta_H_rel=2.022e-01 res=6.071e-01, ||g||=6.358e-01, J=2.229772e+00 terminal_cost = 2.023062229156494
# iter 012, ls=0, delta_control_rel=3.685e-01, delta_H_rel=1.806e-01 res=5.516e-01, ||g||=5.843e-01, J=2.197009e+00 terminal_cost = 1.9732179641723633
# iter 013, ls=0, delta_control_rel=3.488e-01, delta_H_rel=1.612e-01 res=5.022e-01, ||g||=5.391e-01, J=2.169084e+00 terminal_cost = 1.9289402961730957
# iter 014, ls=0, delta_control_rel=3.301e-01, delta_H_rel=1.437e-01 res=4.578e-01, ||g||=4.989e-01, J=2.145133e+00 terminal_cost = 1.8893492221832275
# iter 015, ls=0, delta_control_rel=3.124e-01, delta_H_rel=1.280e-01 res=4.179e-01, ||g||=4.631e-01, J=2.124480e+00 terminal_cost = 1.8537465333938599
# iter 016, ls=0, delta_control_rel=2.955e-01, delta_H_rel=1.140e-01 res=3.818e-01, ||g||=4.308e-01, J=2.106586e+00 terminal_cost = 1.821570873260498
# iter 017, ls=0, delta_control_rel=2.796e-01, delta_H_rel=1.014e-01 res=3.492e-01, ||g||=4.017e-01, J=2.091018e+00 terminal_cost = 1.7923641204833984
# iter 018, ls=0, delta_control_rel=2.645e-01, delta_H_rel=9.035e-02 res=3.197e-01, ||g||=3.753e-01, J=2.077422e+00 terminal_cost = 1.7657490968704224
# iter 019, ls=0, delta_control_rel=2.504e-01, delta_H_rel=8.063e-02 res=2.932e-01, ||g||=3.512e-01, J=2.065807e+00 terminal_cost = 1.7420759201049805
# iter 020, ls=0, delta_control_rel=2.372e-01, delta_H_rel=7.217e-02 res=2.697e-01, ||g||=3.297e-01, J=2.056174e+00 terminal_cost = 1.7215020656585693
# iter 021, ls=0, delta_control_rel=2.250e-01, delta_H_rel=6.477e-02 res=2.490e-01, ||g||=3.110e-01, J=2.048106e+00 terminal_cost = 1.7034578323364258
# iter 022, ls=0, delta_control_rel=2.136e-01, delta_H_rel=5.826e-02 res=2.307e-01, ||g||=2.945e-01, J=2.041293e+00 terminal_cost = 1.6875081062316895
# iter 023, ls=0, delta_control_rel=2.030e-01, delta_H_rel=5.251e-02 res=2.143e-01, ||g||=2.799e-01, J=2.035498e+00 terminal_cost = 1.6733137369155884
# iter 024, ls=0, delta_control_rel=1.930e-01, delta_H_rel=4.743e-02 res=1.995e-01, ||g||=2.670e-01, J=2.030537e+00 terminal_cost = 1.6606050729751587
# iter 025, ls=0, delta_control_rel=1.837e-01, delta_H_rel=4.291e-02 res=1.862e-01, ||g||=2.554e-01, J=2.026265e+00 terminal_cost = 1.649167537689209
# iter 026, ls=0, delta_control_rel=1.749e-01, delta_H_rel=3.889e-02 res=1.741e-01, ||g||=2.450e-01, J=2.022568e+00 terminal_cost = 1.6388237476348877
# iter 027, ls=0, delta_control_rel=1.666e-01, delta_H_rel=3.530e-02 res=1.631e-01, ||g||=2.357e-01, J=2.019354e+00 terminal_cost = 1.6294296979904175
# iter 028, ls=0, delta_control_rel=1.588e-01, delta_H_rel=3.209e-02 res=1.531e-01, ||g||=2.272e-01, J=2.016549e+00 terminal_cost = 1.6208665370941162
# iter 029, ls=0, delta_control_rel=1.515e-01, delta_H_rel=2.921e-02 res=1.439e-01, ||g||=2.195e-01, J=2.014091e+00 terminal_cost = 1.6130344867706299
# iter 030, ls=0, delta_control_rel=1.446e-01, delta_H_rel=2.662e-02 res=1.354e-01, ||g||=2.126e-01, J=2.011929e+00 terminal_cost = 1.605846881866455
# iter 031, ls=0, delta_control_rel=1.380e-01, delta_H_rel=2.429e-02 res=1.276e-01, ||g||=2.062e-01, J=2.010022e+00 terminal_cost = 1.5992332696914673
# iter 032, ls=0, delta_control_rel=1.318e-01, delta_H_rel=2.218e-02 res=1.204e-01, ||g||=2.005e-01, J=2.008336e+00 terminal_cost = 1.5931304693222046
# iter 033, ls=0, delta_control_rel=1.259e-01, delta_H_rel=2.029e-02 res=1.137e-01, ||g||=1.952e-01, J=2.006840e+00 terminal_cost = 1.5874876976013184
# iter 034, ls=0, delta_control_rel=1.204e-01, delta_H_rel=1.857e-02 res=1.075e-01, ||g||=1.903e-01, J=2.005509e+00 terminal_cost = 1.582256555557251
# iter 035, ls=0, delta_control_rel=1.151e-01, delta_H_rel=1.701e-02 res=1.018e-01, ||g||=1.859e-01, J=2.004324e+00 terminal_cost = 1.5773980617523193
# iter 036, ls=0, delta_control_rel=1.101e-01, delta_H_rel=1.560e-02 res=9.640e-02, ||g||=1.818e-01, J=2.003265e+00 terminal_cost = 1.572877287864685
# No control   J_no:con  = 4.378182e+00, terminal cost = 4.378182e+00
# 0.0015976876

# %%
# --------------------------------------------------------------------
# 6.  Plots
# --------------------------------------------------------------------


weight_str = f"w_{weight}_"

plot_controls(no_control, optimal_control, u_min, u_max, name = weight_str + 'controls.png', output_dir = output_dir)

plot_densities(state0, state_T_adj, state_T_no_control, lower_bound, upper_bound, name = weight_str + 'densities.png', output_dir = output_dir)

plot_all_residuals(delta_control_adj[:-1], delta_H_adj[:-1], res_hist_adj, y_min=0.001, y_max=3.5, tol=1e-1, name = weight_str + 'residuals.png', output_dir = output_dir, mark_every=1)

plot_objective(loss_hist_adj, terminal_hist_adj, name = weight_str + 'loss.png', output_dir = output_dir, markevery=2)

plt.show()

# %%
# --------------------------------------------------------------------
# 6.  Saving Data
# --------------------------------------------------------------------

import numpy as np
from pathlib import Path

# make sure directory exists
output_dir = Path(output_dir)
output_dir.mkdir(parents=True, exist_ok=True)

delta_control_filename = f"{weight_str}delta_control.npy"
delta_control_filepath = output_dir / delta_control_filename
np.save(delta_control_filepath, np.array(delta_control_adj)) 

delta_H_filename = f"{weight_str}delta_H.npy"
delta_H_filepath = output_dir / delta_H_filename
np.save(delta_H_filepath, np.array(delta_H_adj)) 

residual_filename = f"{weight_str}projection_residual.npy"
residual_filepath = output_dir / residual_filename
np.save(residual_filepath, np.array(res_hist_adj)) 

loss_filename = f"{weight_str}loss.npy"
loss_filepath = output_dir / loss_filename
np.save(loss_filepath, np.array(loss_hist_adj)) 

terminal_filename = f"{weight_str}terminal_cost.npy"
terminal_filepath = output_dir / terminal_filename
np.save(terminal_filepath, np.array(terminal_hist_adj)) 

control_filename = f"{weight_str}optimal_control.npy"
control_filepath = output_dir / control_filename
np.save(control_filepath, np.array(optimal_control)) 

animation_filename = f"{weight_str}animations.gif"
animation_filepath = output_dir / animation_filename
